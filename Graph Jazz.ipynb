# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# To import libraries
comp_deaths_hospitals = pd.read_csv("Complications and Deaths - Hospital.csv", low_memory=False)
readdmissions = pd.read_csv("Readmissions and Deaths - VA_07_10_2018.csv", low_memory=False)
medicare = pd.read_csv("Medicare Hospital Spending per Patient - Hospital.csv", low_memory=False)
u_visits = pd.read_csv("Unplanned Hospital Visits - Hospital.csv", low_memory=False)

comp_deaths_hospitals_ks_mo = comp_deaths_hospitals[(comp_deaths_hospitals['State']=='KS')|(comp_deaths_hospitals['State']=='MO')]
readdmissions_ks_mo = readdmissions[(readdmissions['State']=='KS')|(readdmissions['State']=='MO')]
medicare_ks_mo = medicare[(medicare['State']=='KS')|(medicare['State']=='MO')]
u_visits_ks_mo = u_visits[(u_visits['State']=='KS')|(u_visits['State']=='MO')]

comp_deaths_hospitals_county = comp_deaths_hospitals_ks_mo[(comp_deaths_hospitals['County Name']=='JACKSON')|
                                               (comp_deaths_hospitals['County Name']=='JOHNSON')|
                                               (comp_deaths_hospitals['County Name']=='CLAY')|
                                               (comp_deaths_hospitals['County Name']=='LEAVENWORTH')|
                                               (comp_deaths_hospitals['County Name']=='WYANDOTTE')]

readdmissions_county = readdmissions_ks_mo[(readdmissions['County']=='JACKSON')|
                                    (readdmissions['County']=='JOHNSON')|
                                    (readdmissions['County']=='CLAY')|
                                    (readdmissions['County']=='LEAVENWORTH')|
                                    (readdmissions['County']=='WYANDOTTE')]
                                      
medicare_county = medicare_ks_mo[(medicare['County Name']=='JACKSON')|
                          (medicare['County Name']=='JOHNSON')|
                          (medicare['County Name']=='CLAY')|
                          (medicare['County Name']=='LEAVENWORTH')|
                          (medicare['County Name']=='WYANDOTTE')]

u_visits_county = u_visits_ks_mo[(u_visits['County Name']=='JACKSON')|
                          (u_visits['County Name']=='JOHNSON')|
                          (u_visits['County Name']=='CLAY')|
                          (u_visits['County Name']=='LEAVENWORTH')|
                          (u_visits['County Name']=='WYANDOTTE')]

comp_deaths_hospitals_county = comp_deaths_hospitals_county[['Provider ID', 'Hospital Name', 'Address', 'City',
                                                             'State', 'ZIP Code','County Name', 'Measure Name', 
                                                             'Measure ID','Compared to National', 'Score']]

readdmissions_county = readdmissions_county[['Provider_ID', 'Hospital Name', 'Address', 'City', 'State', 'ZIP Code',
                                             'County', 'Measure Name', 'Measure ID', 'Score']]

medicare_county = medicare_county[['Provider ID', 'Hospital Name', 'Address', 'City', 'State', 'ZIP Code',
                                   'County Name', 'Measure Name', 'Measure ID', 
                                   'Score']]

u_visits_county = u_visits_county[['Provider ID', 'Hospital Name', 'Address', 'City', 'State', 'ZIP Code',
                                   'County Name', 'Measure Name', 'Measure ID','Compared to National', 
                                   'Score']]

# %%
# Graph Jazz
# Question 1
# If a county has higher medicare spending, then they should have less deaths/post-hospital accidents.
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='r', marker='o', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='b', marker='^', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='s', marker='s', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='black', marker='d', markersize=5, linestyle='--', linewidth=0.5)
plt.grid()
plt.title("High Medicare Spending vs Deaths/Accidents after Operation")
plt.xlabel("Medicare Spending")
plt.ylabel("Deaths/Accidents after Operation")
plt.legend(loc="upper left")
plt.savefig("medicare_spending_vs_postop_danger.png")

# Question 2
# If a county has higher medicare spending, then they should have less readmissions.
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='r', marker='o', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='b', marker='^', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='s', marker='s', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='black', marker='d', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='magenta', marker='*', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='cyan', marker='p', markersize=5, linestyle='--', linewidth=0.5)
plt.grid()
plt.title("High Medicare Spending vs Readmissions")
plt.xlabel("Medicare Spending")
plt.ylabel("Readmissions")
plt.legend(loc="upper left")
plt.savefig("medicare_spending_vs_readmissions.png")

# Question 3
# Which county has the greatest count of data recordings? AKA, which county has the least “not available” data?
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='r', marker='o', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='b', marker='^', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='s', marker='s', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='black', marker='d', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='magenta', marker='*', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='cyan', marker='p', markersize=5, linestyle='--', linewidth=0.5)
plt.grid()
plt.title("Amount of Data Recorded by County")
plt.xlabel("County")
plt.ylabel("Data Available")
plt.legend(loc="upper left")
plt.savefig("amount_of_data_recorded_by_county.png")

# Question 4
# If a county is good at recording their data, then they should have less readmissions. 
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='r', marker='o', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='b', marker='^', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='s', marker='s', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='black', marker='d', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='magenta', marker='*', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='cyan', marker='p', markersize=5, linestyle='--', linewidth=0.5)
plt.grid()
plt.title("Data Recorded vs Readmissions")
plt.xlabel("Data Recorded")
plt.ylabel("Readmissions")
plt.legend(loc="upper left")
plt.savefig("data_recorded_vs_readmissions.png")

# Question 5
# Is there a relationship between higher medicare spending and how much data is recorded?
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='r', marker='o', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='b', marker='^', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='s', marker='s', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='black', marker='d', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='magenta', marker='*', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='cyan', marker='p', markersize=5, linestyle='--', linewidth=0.5)
plt.grid()
plt.title("Medicare Money Spent vs Amount of Data Recorded")
plt.xlabel("Medicare Money Spent")
plt.ylabel("Amount of Data Recorded")
plt.legend(loc="upper left")
plt.savefig("medicare_spending_vs_data_recorded.png")


# Question 6
# If a county has lower medicare spending, then there are more unexpected hospital visits.
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='r', marker='o', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='b', marker='^', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='s', marker='s', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='black', marker='d', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='magenta', marker='*', markersize=5, linestyle='--', linewidth=0.5)
plt.errorbar(main_table, main_table['column'], yerr=sem_error['column'],
            color='cyan', marker='p', markersize=5, linestyle='--', linewidth=0.5)
plt.grid()
plt.title("Low Medicare Spending vs Unexpected Hospital Visits")
plt.xlabel("Unexpected Hospital Visits")
plt.ylabel("Low Medicare Spending")
plt.legend(loc="upper left")
plt.savefig("medicare_vs_expected_visits.png")
