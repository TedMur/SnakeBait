# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# To import libraries
comp_deaths_hospitals = pd.read_csv("Complications and Deaths - Hospital 6.csv", low_memory=False)
readdmissions = pd.read_csv("Readmissions and Deaths - VA_07_10_2018 6.csv", low_memory=False)
medicare = pd.read_csv("Medicare Hospital Spending per Patient - Hospital 6.csv", low_memory=False)
u_visits = pd.read_csv("Unplanned Hospital Visits - Hospital 6.csv", low_memory=False)

comp_deaths_hospitals_ks_mo = comp_deaths_hospitals[(comp_deaths_hospitals['State']=='KS')|(comp_deaths_hospitals['State']=='MO')]
readdmissions_ks_mo = readdmissions[(readdmissions['State']=='KS')|(readdmissions['State']=='MO')]
medicare_ks_mo = medicare[(medicare['State']=='KS')|(medicare['State']=='MO')]
u_visits_ks_mo = u_visits[(u_visits['State']=='KS')|(u_visits['State']=='MO')]

comp_deaths_hospitals_county = comp_deaths_hospitals_ks_mo[(comp_deaths_hospitals['County Name']=='JACKSON')|
                                               (comp_deaths_hospitals['County Name']=='JOHNSON')|
                                               (comp_deaths_hospitals['County Name']=='CLAY')|
                                               (comp_deaths_hospitals['County Name']=='LEAVENWORTH')|
                                               (comp_deaths_hospitals['County Name']=='SEDGWICK')|
                                               (comp_deaths_hospitals['County Name']=='WYANDOTTE')]

readdmissions_county = readdmissions_ks_mo[(readdmissions['County']=='JACKSON')|
                                    (readdmissions['County']=='JOHNSON')|
                                    (readdmissions['County']=='CLAY')|
                                    (readdmissions['County']=='LEAVENWORTH')|
                                    (readdmissions['County']=='SEDGWICK')|
                                    (readdmissions['County']=='WYANDOTTE')]
                                      
medicare_county = medicare_ks_mo[(medicare['County Name']=='JACKSON')|
                          (medicare['County Name']=='JOHNSON')|
                          (medicare['County Name']=='CLAY')|
                          (medicare['County Name']=='LEAVENWORTH')|
                          (medicare['County Name']=='SEDGWICK')|
                          (medicare['County Name']=='WYANDOTTE')]

u_visits_county = u_visits_ks_mo[(u_visits['County Name']=='JACKSON')|
                          (u_visits['County Name']=='JOHNSON')|
                          (u_visits['County Name']=='CLAY')|
                          (u_visits['County Name']=='LEAVENWORTH')|
                          (u_visits['County Name']=='SEDGWICK')|
                          (u_visits['County Name']=='WYANDOTTE')]
# Out:
# C:\Users\Sasha\Anaconda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:35: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
jackson_u = u_visits_county[(u_visits['County Name']=='JACKSON')]
jackson_medi = medicare_county[(medicare_ks_mo['County Name']=='JACKSON')]
jackson_read = readdmissions_county[(readdmissions_ks_mo['County']=='JACKSON')]
jackson_death = comp_deaths_hospitals_county[(comp_deaths_hospitals_ks_mo['County Name']=='JACKSON')]

jackson_u
# Out:
#      Provider ID                            Hospital Name  \
# 36        260027                  RESEARCH MEDICAL CENTER
# 37        260027                  RESEARCH MEDICAL CENTER
# 38        260027                  RESEARCH MEDICAL CENTER
# 39        260027                  RESEARCH MEDICAL CENTER
# 40        260027                  RESEARCH MEDICAL CENTER
# 41        260027                  RESEARCH MEDICAL CENTER
# 42        260027                  RESEARCH MEDICAL CENTER
# 43        260027                  RESEARCH MEDICAL CENTER
# 44        260027                  RESEARCH MEDICAL CENTER
# 154       263302                 CHILDRENS MERCY HOSPITAL
# 155       263302                 CHILDRENS MERCY HOSPITAL
#
#                             Address          City State  Zip Code County Name  \
# 36                2316 E MEYER BLVD   KANSAS CITY    MO     64132     JACKSON
# 37                2316 E MEYER BLVD   KANSAS CITY    MO     64132     JACKSON
# 38                2316 E MEYER BLVD   KANSAS CITY    MO     64132     JACKSON
# 39                2316 E MEYER BLVD   KANSAS CITY    MO     64132     JACKSON
# 40                2316 E MEYER BLVD   KANSAS CITY    MO     64132     JACKSON
# 41                2316 E MEYER BLVD   KANSAS CITY    MO     64132     JACKSON
# 42                2316 E MEYER BLVD   KANSAS CITY    MO     64132     JACKSON
# 43                2316 E MEYER BLVD   KANSAS CITY    MO     64132     JACKSON
# 44                2316 E MEYER BLVD   KANSAS CITY    MO     64132     JACKSON
# 45                2316 E MEYER BLVD   KANSAS CITY    MO     64132     JACKSON
# 46                2316 E MEYER BLVD   KANSAS CITY    MO     64132     JACKSON
# 47                2316 E MEYER BLVD   KANSAS CITY    MO     64132     JACKSON
# 48               2301 HOLMES STREET   KANSAS CITY    MO     64108     JACKSON
# 49               2301 HOLMES STREET   KANSAS CITY    MO     64108     JACKSON
# 50               2301 HOLMES STREET   KANSAS CITY    MO     64108     JACKSON
# 51               2301 HOLMES STREET   KANSAS CITY    MO     64108     JACKSON
# 52               2301 HOLMES STREET   KANSAS CITY    MO     64108     JACKSON
# 53               2301 HOLMES STREET   KANSAS CITY    MO     64108     JACKSON
# 54               2301 HOLMES STREET   KANSAS CITY    MO     64108     JACKSON
# 55               2301 HOLMES STREET   KANSAS CITY    MO     64108     JACKSON
# 56               2301 HOLMES STREET   KANSAS CITY    MO     64108     JACKSON
# 57               2301 HOLMES STREET   KANSAS CITY    MO     64108     JACKSON
# 58               2301 HOLMES STREET   KANSAS CITY    MO     64108     JACKSON
# 59               2301 HOLMES STREET   KANSAS CITY    MO     64108     JACKSON
# 60               1000 CARONDELET DR   KANSAS CITY    MO     64114     JACKSON
# 61               1000 CARONDELET DR   KANSAS CITY    MO     64114     JACKSON
# 62               1000 CARONDELET DR   KANSAS CITY    MO     64114     JACKSON
# 63               1000 CARONDELET DR   KANSAS CITY    MO     64114     JACKSON
# 64               1000 CARONDELET DR   KANSAS CITY    MO     64114     JACKSON
# 65               1000 CARONDELET DR   KANSAS CITY    MO     64114     JACKSON
# ..                              ...           ...   ...       ...         ...
# 126              201 NW R D MIZE RD  BLUE SPRINGS    MO     64014     JACKSON
# 127              201 NW R D MIZE RD  BLUE SPRINGS    MO     64014     JACKSON
# 128              201 NW R D MIZE RD  BLUE SPRINGS    MO     64014     JACKSON
# 129              201 NW R D MIZE RD  BLUE SPRINGS    MO     64014     JACKSON
# 130              201 NW R D MIZE RD  BLUE SPRINGS    MO     64014     JACKSON
# 131              201 NW R D MIZE RD  BLUE SPRINGS    MO     64014     JACKSON
# 132  100 N E SAINT LUKE'S BOULEVARD   LEES SUMMIT    MO     64086     JACKSON
# 133  100 N E SAINT LUKE'S BOULEVARD   LEES SUMMIT    MO     64086     JACKSON
# 134  100 N E SAINT LUKE'S BOULEVARD   LEES SUMMIT    MO     64086     JACKSON
# 135  100 N E SAINT LUKE'S BOULEVARD   LEES SUMMIT    MO     64086     JACKSON
# 136  100 N E SAINT LUKE'S BOULEVARD   LEES SUMMIT    MO     64086     JACKSON
# 137  100 N E SAINT LUKE'S BOULEVARD   LEES SUMMIT    MO     64086     JACKSON
# 138  100 N E SAINT LUKE'S BOULEVARD   LEES SUMMIT    MO     64086     JACKSON
# 139  100 N E SAINT LUKE'S BOULEVARD   LEES SUMMIT    MO     64086     JACKSON
# 140  100 N E SAINT LUKE'S BOULEVARD   LEES SUMMIT    MO     64086     JACKSON
# 141  100 N E SAINT LUKE'S BOULEVARD   LEES SUMMIT    MO     64086     JACKSON
# 142  100 N E SAINT LUKE'S BOULEVARD   LEES SUMMIT    MO     64086     JACKSON
# 143  100 N E SAINT LUKE'S BOULEVARD   LEES SUMMIT    MO     64086     JACKSON
# 144               2401 GILLHAM ROAD   KANSAS CITY    MO     64108     JACKSON
# 145               2401 GILLHAM ROAD   KANSAS CITY    MO     64108     JACKSON
# 146               2401 GILLHAM ROAD   KANSAS CITY    MO     64108     JACKSON
# 147               2401 GILLHAM ROAD   KANSAS CITY    MO     64108     JACKSON
# 148               2401 GILLHAM ROAD   KANSAS CITY    MO     64108     JACKSON
# 149               2401 GILLHAM ROAD   KANSAS CITY    MO     64108     JACKSON
# 150               2401 GILLHAM ROAD   KANSAS CITY    MO     64108     JACKSON
# 151               2401 GILLHAM ROAD   KANSAS CITY    MO     64108     JACKSON
# 152               2401 GILLHAM ROAD   KANSAS CITY    MO     64108     JACKSON
# 153               2401 GILLHAM ROAD   KANSAS CITY    MO     64108     JACKSON
# 154               2401 GILLHAM ROAD   KANSAS CITY    MO     64108     JACKSON
# 155               2401 GILLHAM ROAD   KANSAS CITY    MO     64108     JACKSON
#
#      Phone Number                                       Measure Name  \
# 36     8162764000     Hospital return days for heart attack patients
# 37     8162764000    Hospital return days for heart failure patients
# 38     8162764000        Hospital return days for pneumonia patients
# 39     8162764000  Rate of unplanned hospital visits after colono...
# 40     8162764000  Acute Myocardial Infarction (AMI) 30-Day Readm...
# 41     8162764000                       Rate of readmission for CABG
# 42     8162764000  Rate of readmission for chronic obstructive pu...
# 43     8162764000         Heart failure (HF) 30-Day Readmission Rate
# 44     8162764000     Rate of readmission after hip/knee replacement
# 45     8162764000  30-Day Hospital-Wide All-Cause Unplanned Readm...
# 46     8162764000             Pneumonia (PN) 30-Day Readmission Rate
# 47     8162764000            Rate of readmission for stroke patients
# 48     8164041000     Hospital return days for heart attack patients
# 49     8164041000    Hospital return days for heart failure patients
# 50     8164041000        Hospital return days for pneumonia patients
# 51     8164041000  Rate of unplanned hospital visits after colono...
# 52     8164041000  Acute Myocardial Infarction (AMI) 30-Day Readm...
# 53     8164041000                       Rate of readmission for CABG
# 54     8164041000  Rate of readmission for chronic obstructive pu...
# 55     8164041000         Heart failure (HF) 30-Day Readmission Rate
# 56     8164041000     Rate of readmission after hip/knee replacement
# 57     8164041000  30-Day Hospital-Wide All-Cause Unplanned Readm...
# 58     8164041000             Pneumonia (PN) 30-Day Readmission Rate
# 59     8164041000            Rate of readmission for stroke patients
# 60     8169424000     Hospital return days for heart attack patients
# 61     8169424000    Hospital return days for heart failure patients
# 62     8169424000        Hospital return days for pneumonia patients
# 63     8169424000  Rate of unplanned hospital visits after colono...
# 64     8169424000  Acute Myocardial Infarction (AMI) 30-Day Readm...
# 65     8169424000                       Rate of readmission for CABG
# ..            ...                                                ...
# 126    8162285900  Rate of readmission for chronic obstructive pu...
# 127    8162285900         Heart failure (HF) 30-Day Readmission Rate
# 128    8162285900     Rate of readmission after hip/knee replacement
# 129    8162285900  30-Day Hospital-Wide All-Cause Unplanned Readm...
# 130    8162285900             Pneumonia (PN) 30-Day Readmission Rate
# 131    8162285900            Rate of readmission for stroke patients
# 132    8163475000     Hospital return days for heart attack patients
# 133    8163475000    Hospital return days for heart failure patients
# 134    8163475000        Hospital return days for pneumonia patients
# 135    8163475000  Rate of unplanned hospital visits after colono...
# 136    8163475000  Acute Myocardial Infarction (AMI) 30-Day Readm...
# 137    8163475000                       Rate of readmission for CABG
# 138    8163475000  Rate of readmission for chronic obstructive pu...
# 139    8163475000         Heart failure (HF) 30-Day Readmission Rate
# 140    8163475000     Rate of readmission after hip/knee replacement
# 141    8163475000  30-Day Hospital-Wide All-Cause Unplanned Readm...
# 142    8163475000             Pneumonia (PN) 30-Day Readmission Rate
# 143    8163475000            Rate of readmission for stroke patients
# 144    8162343000     Hospital return days for heart attack patients
# 145    8162343000    Hospital return days for heart failure patients
# 146    8162343000        Hospital return days for pneumonia patients
# 147    8162343000  Rate of unplanned hospital visits after colono...
# 148    8162343000  Acute Myocardial Infarction (AMI) 30-Day Readm...
# 149    8162343000                       Rate of readmission for CABG
# 150    8162343000  Rate of readmission for chronic obstructive pu...
# 151    8162343000         Heart failure (HF) 30-Day Readmission Rate
# 152    8162343000     Rate of readmission after hip/knee replacement
# 153    8162343000  30-Day Hospital-Wide All-Cause Unplanned Readm...
# 154    8162343000             Pneumonia (PN) 30-Day Readmission Rate
# 155    8162343000            Rate of readmission for stroke patients
#
#              Measure ID                        Compared to National  \
# 36          EDAC_30_AMI             Average days per 100 discharges
# 37           EDAC_30_HF   More days than average per 100 discharges
# 38           EDAC_30_PN             Average days per 100 discharges
# 39                OP-32         No Different than the National Rate
# 40         READM_30_AMI         No Different than the National Rate
# 41        READM_30_CABG         No Different than the National Rate
# 42        READM_30_COPD         No Different than the National Rate
# 43          READM_30_HF         No Different than the National Rate
# 44    READM_30_HIP_KNEE         No Different than the National Rate
# 45   READM_30_HOSP_WIDE                Worse than the National Rate
# 46          READM_30_PN         No Different than the National Rate
# 47         READM_30_STK         No Different than the National Rate
# 48          EDAC_30_AMI                   Number of Cases Too Small
# 49           EDAC_30_HF             Average days per 100 discharges
# 50           EDAC_30_PN   More days than average per 100 discharges
# 51                OP-32         No Different than the National Rate
# 52         READM_30_AMI                   Number of Cases Too Small
# 53        READM_30_CABG                               Not Available
# 54        READM_30_COPD         No Different than the National Rate
# 55          READM_30_HF         No Different than the National Rate
# 56    READM_30_HIP_KNEE         No Different than the National Rate
# 57   READM_30_HOSP_WIDE         No Different than the National Rate
# 58          READM_30_PN         No Different than the National Rate
# 59         READM_30_STK         No Different than the National Rate
# 60          EDAC_30_AMI  Fewer days than average per 100 discharges
# 61           EDAC_30_HF             Average days per 100 discharges
# 62           EDAC_30_PN             Average days per 100 discharges
# 63                OP-32         No Different than the National Rate
# 64         READM_30_AMI         No Different than the National Rate
# 65        READM_30_CABG         No Different than the National Rate
# ..                  ...                                         ...
# 126       READM_30_COPD         No Different than the National Rate
# 127         READM_30_HF         No Different than the National Rate
# 128   READM_30_HIP_KNEE         No Different than the National Rate
# 129  READM_30_HOSP_WIDE                Worse than the National Rate
# 130         READM_30_PN                Worse than the National Rate
# 131        READM_30_STK         No Different than the National Rate
# 132         EDAC_30_AMI             Average days per 100 discharges
# 133          EDAC_30_HF             Average days per 100 discharges
# 134          EDAC_30_PN             Average days per 100 discharges
# 135               OP-32         No Different than the National Rate
# 136        READM_30_AMI         No Different than the National Rate
# 137       READM_30_CABG                   Number of Cases Too Small
# 138       READM_30_COPD         No Different than the National Rate
# 139         READM_30_HF         No Different than the National Rate
# 140   READM_30_HIP_KNEE         No Different than the National Rate
# 141  READM_30_HOSP_WIDE         No Different than the National Rate
# 142         READM_30_PN         No Different than the National Rate
# 143        READM_30_STK         No Different than the National Rate
# 144         EDAC_30_AMI                               Not Available
# 145          EDAC_30_HF                               Not Available
# 146          EDAC_30_PN                               Not Available
# 147               OP-32                               Not Available
# 148        READM_30_AMI                               Not Available
# 149       READM_30_CABG                               Not Available
# 150       READM_30_COPD                               Not Available
# 151         READM_30_HF                               Not Available
# 152   READM_30_HIP_KNEE                               Not Available
# 153  READM_30_HOSP_WIDE                               Not Available
# 154         READM_30_PN                               Not Available
# 155        READM_30_STK                               Not Available
#
#        Denominator          Score Lower Estimate Higher Estimate  \
# 36             159           15.1           -4.8            37.7
# 37             246           26.7            1.7            53.6
# 38             280           10.1           -8.7            31.2
# 39             206           18.3           12.7            26.4
# 40             159           17.7           14.6            21.2
# 41              46           13.5            9.9            17.9
# 42             264           20.3           17.5            23.4
# 43             246           23.2           19.8            26.9
# 44              67            4.4              3             6.4
# 45            2375           16.5           15.4            17.5
# 46             280           17.9           15.2              21
# 47             212             12            9.6              15
# 48   Not Available  Not Available  Not Available   Not Available
# 49              89           32.5             -5            75.4
# 50              74           37.8            7.5            77.1
# 51             120           17.4           12.1            25.1
# 52   Not Available  Not Available  Not Available   Not Available
# 53   Not Available  Not Available  Not Available   Not Available
# 54              89           19.8           16.7            23.5
# 55              89             20           16.1            24.4
# 56              28            4.3              3             6.2
# 57             574           16.2             15            17.5
# 58              74           17.7           14.2            21.8
# 59              26           11.3            8.7            14.6
# 60             244          -22.8          -37.2            -6.6
# 61             467            7.8           -9.7            27.3
# 62             887           -0.6          -12.8            11.5
# 63             306           19.2           13.6            26.9
# 141                                                NaN           7/1/2016
# 142                                                NaN           7/1/2014
# 143                                                NaN           7/1/2014
# 144  5 - Results are not available for this reporti...           7/1/2014
# 145  5 - Results are not available for this reporti...           7/1/2014
# 146  5 - Results are not available for this reporti...           7/1/2014
# 147  5 - Results are not available for this reporti...           1/1/2016
# 148  5 - Results are not available for this reporti...           7/1/2014
# 149  5 - Results are not available for this reporti...           7/1/2014
# 150  5 - Results are not available for this reporti...           7/1/2014
# 151  5 - Results are not available for this reporti...           7/1/2014
# 152  5 - Results are not available for this reporti...           7/1/2014
# 153  5 - Results are not available for this reporti...           7/1/2016
# 154  5 - Results are not available for this reporti...           7/1/2014
# 155  5 - Results are not available for this reporti...           7/1/2014
#
#     Measure End Date
# 36         6/30/2017
# 37         6/30/2017
# 38         6/30/2017
# 39        12/31/2016
# 40         6/30/2017
# 41         6/30/2017
# 42         6/30/2017
# 43         6/30/2017
# 44         6/30/2017
# 45         6/30/2017
# 46         6/30/2017
# 47         6/30/2017
# 48         6/30/2017
# 49         6/30/2017
# 50         6/30/2017
# 51        12/31/2016
# 52         6/30/2017
# 53         6/30/2017
# 54         6/30/2017
# 55         6/30/2017
# 56         6/30/2017
# 57         6/30/2017
# 58         6/30/2017
# 59         6/30/2017
# 60         6/30/2017
# 61         6/30/2017
# 62         6/30/2017
# 63        12/31/2016
# 64         6/30/2017
# 65         6/30/2017
# ..               ...
# 126        6/30/2017
# 127        6/30/2017
# 128        6/30/2017
# 129        6/30/2017
# 130        6/30/2017
# 131        6/30/2017
# 132        6/30/2017
# 133        6/30/2017
# 134        6/30/2017
# 135       12/31/2016
# 136        6/30/2017
# 137        6/30/2017
# 138        6/30/2017
# 139        6/30/2017
# 140        6/30/2017
# 141        6/30/2017
# 142        6/30/2017
# 143        6/30/2017
# 144        6/30/2017
# 145        6/30/2017
# 146        6/30/2017
# 147       12/31/2016
# 148        6/30/2017
# 149        6/30/2017
# 150        6/30/2017
# 151        6/30/2017
# 152        6/30/2017
# 153        6/30/2017
# 154        6/30/2017
# 155        6/30/2017
#
# [120 rows x 18 columns]

# %%
county = [counties for counties in medicare_county['Score']]

ind = np.arange(len(county))
plt.bar(county, ind)
plt.ylabel('Scores')
plt.title('Medicare Scores by County')
plt.xticks(county, ind)
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
bleh = [counties for counties in u_visits_county['Score']]

beep = np.arange(len(bleh))
plt.bar(beep, bleh)
plt.ylabel('Scores')
plt.title('Unexpected Visit Scores by County')
plt.xticks(beep, bleh)
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
nikes = [counties for counties in readdmissions_county['Score']]

adidas = np.arange(len(nikes))
plt.bar(adidas, nikes)
plt.ylabel('Scores')
plt.title('Readmission Scores by County')
plt.xticks(adidas, nikes)
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# comp_deaths_hospitals_county

jazz = [counties for counties in comp_deaths_hospitals_county['Score']]

hands = np.arange(len(jazz))
plt.bar(jazz, hands)
plt.ylabel('Scores')
plt.title('Complications/Deaths Scores by County')
plt.xticks(jazz, hands)
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.
