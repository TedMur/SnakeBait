# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
comp_deaths_hospitals = pd.read_csv("Complications and Deaths - Hospital.csv", low_memory=False)
readdmissions = pd.read_csv("Readmissions and Deaths - VA_07_10_2018.csv", low_memory=False)
medicare = pd.read_csv("Medicare Hospital Spending per Patient - Hospital.csv", low_memory=False)
u_visits = pd.read_csv("Unplanned Hospital Visits - Hospital.csv", low_memory=False)
#comp_deaths_hospitals.head(10)
comp_deaths_hospitals.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-1a4848c12344> in <module>
# ----> 1 comp_deaths_hospitals = pd.read_csv("Complications and Deaths - Hospital.csv", low_memory=False)
#       2 readdmissions = pd.read_csv("Readmissions and Deaths - VA_07_10_2018.csv", low_memory=False)
#       3 medicare = pd.read_csv("Medicare Hospital Spending per Patient - Hospital.csv", low_memory=False)
#       4 u_visits = pd.read_csv("Unplanned Hospital Visits - Hospital.csv", low_memory=False)
#       5 #comp_deaths_hospitals.head(10)
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'Complications and Deaths - Hospital.csv' does not exist

# %%
readdmissions.head()
# Out:
#   Provider_ID                 Hospital Name                Address  \
# 0      01014F  BIRMINGHAM VA MEDICAL CENTER  700 SOUTH 19TH STREET
# 1      01014F  BIRMINGHAM VA MEDICAL CENTER  700 SOUTH 19TH STREET
# 2      01014F  BIRMINGHAM VA MEDICAL CENTER  700 SOUTH 19TH STREET
# 3      01014F  BIRMINGHAM VA MEDICAL CENTER  700 SOUTH 19TH STREET
# 4      01014F  BIRMINGHAM VA MEDICAL CENTER  700 SOUTH 19TH STREET
#
#          City State  ZIP Code     County  \
# 0  BIRMINGHAM    AL     35233  JEFFERSON
# 1  BIRMINGHAM    AL     35233  JEFFERSON
# 2  BIRMINGHAM    AL     35233  JEFFERSON
# 3  BIRMINGHAM    AL     35233  JEFFERSON
# 4  BIRMINGHAM    AL     35233  JEFFERSON
#
#                                         Measure Name    Measure ID  \
# 0  Acute Myocardial Infarction (AMI) 30-Day Morta...   MORT-30-AMI
# 1           Heart failure (HF) 30-Day Mortality Rate    MORT-30-HF
# 2               Pneumonia (PN) 30-Day Mortality Rate    MORT-30-PN
# 3  Acute Myocardial Infarction (AMI) 30-Day Readm...  READM-30-AMI
# 4         Heart failure (HF) 30-Day Readmission Rate   READM-30-HF
#
#    National Rate                  Compare to National  Denominator  Score  \
# 0            NaN  No Different than the National Rate        112.0   12.6
# 1            NaN        Better than the National Rate        414.0    8.8
# 2            NaN  No Different than the National Rate        199.0   13.5
# 3            NaN  No Different than the National Rate        117.0   16.5
# 4            NaN  No Different than the National Rate        581.0   24.0
#
#    Lower Estimate  Higher Estimate  Footnotes Measure Start Date  \
# 0             9.4             16.4        NaN           7/1/2014
# 1             6.9             11.6        NaN           7/1/2014
# 2            10.6             17.2        NaN           7/1/2014
# 3            13.1             20.7        NaN           7/1/2014
# 4            21.0             27.3        NaN           7/1/2014
#
#   Measure End Date
# 0        6/30/2017
# 1        6/30/2017
# 2        6/30/2017
# 3        6/30/2017
# 4        6/30/2017

# %%
medicare.head()
# Out:
#    Provider ID                     Hospital Name                     Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1        10005     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 2        10006    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET
# 3        10007          MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 4        10008       CRENSHAW COMMUNITY HOSPITAL         101 HOSPITAL CIRCLE
#
#        City State  ZIP Code County Name  Phone Number  \
# 0    DOTHAN    AL     36301     HOUSTON    3347938701
# 1      BOAZ    AL     35957    MARSHALL    2565938310
# 2  FLORENCE    AL     35631  LAUDERDALE    2567688400
# 3       OPP    AL     36467   COVINGTON    3344933541
# 4   LUVERNE    AL     36049    CRENSHAW    3343353374
#
#                                         Measure Name Measure ID Score  \
# 0  Medicare hospital spending per patient (Medica...     MSPB-1  0.99
# 1  Medicare hospital spending per patient (Medica...     MSPB-1     1
# 2  Medicare hospital spending per patient (Medica...     MSPB-1     1
# 3  Medicare hospital spending per patient (Medica...     MSPB-1  1.06
# 4  Medicare hospital spending per patient (Medica...     MSPB-1  0.92
#
#   Footnote Measure Start Date Measure End Date
# 0      NaN         01/01/2016       12/31/2016
# 1      NaN         01/01/2016       12/31/2016
# 2      NaN         01/01/2016       12/31/2016
# 3      NaN         01/01/2016       12/31/2016
# 4      NaN         01/01/2016       12/31/2016

# %%
u_visits.head()
# Out:
#   Provider ID                     Hospital Name                 Address  \
# 0       10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1       10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2       10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3       10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4       10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name  Phone Number  \
# 0  DOTHAN    AL     36301     HOUSTON    3347938701
# 1  DOTHAN    AL     36301     HOUSTON    3347938701
# 2  DOTHAN    AL     36301     HOUSTON    3347938701
# 3  DOTHAN    AL     36301     HOUSTON    3347938701
# 4  DOTHAN    AL     36301     HOUSTON    3347938701
#
#                                         Measure Name    Measure ID  \
# 0     Hospital return days for heart attack patients   EDAC_30_AMI
# 1    Hospital return days for heart failure patients    EDAC_30_HF
# 2        Hospital return days for pneumonia patients    EDAC_30_PN
# 3  Rate of unplanned hospital visits after colono...         OP-32
# 4  Acute Myocardial Infarction (AMI) 30-Day Readm...  READM_30_AMI
#
#                         Compared to National Denominator Score Lower Estimate  \
# 0            Average days per 100 discharges         798  -5.9          -15.9
# 1  More days than average per 100 discharges        1060  17.1            3.4
# 2            Average days per 100 discharges         603   8.4           -5.9
# 3        No Different than the National Rate         255  14.8           10.2
# 4        No Different than the National Rate         798  15.9           13.8
#
#   Higher Estimate Footnote Measure Start Date Measure End Date
# 0             4.8      NaN           7/1/2014        6/30/2017
# 1            31.7      NaN           7/1/2014        6/30/2017
# 2            24.4      NaN           7/1/2014        6/30/2017
# 3              21      NaN           1/1/2016       12/31/2016
# 4            18.2      NaN           7/1/2014        6/30/2017

# %%
comp_deaths_min = comp_deaths_hospitals[["Hospital Name", "Address", "City", "State", "County Name", "Measure Name", "Measure ID"]]
#comp_deaths_min.head()
# Out:
# State  Measure Name
# AK     A wound that splits open after surgery on the abdomen or pelvis    22
#        Accidental cuts and tears from medical treatment                   22
#        Blood stream infection after surgery                               22
#        Broken hip from a fall after surgery                               22
#        Collapsed lung due to medical treatment                            22
# Name: Measure ID, dtype: int64

# %%
#readmissions
#medicare
#u_visits

readmit_min = readdmissions[["County", "Measure Name", "Measure ID", "Compare to National", "Denominator", "Score", "Lower Estimate", "Higher Estimate"]]
medi_min = medicare[["County Name", "Measure Name", "Measure ID", "Score"]]
u_min = u_visits[["County Name", "Measure Name", "Measure ID", "Compared to National", "Denominator", "Score", "Lower Estimate", "Higher Estimate" ]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e25befcd267a> in <module>
#       3 #u_visits
#       4
# ----> 5 readmit_min = readdmissions[["County", "Measure Name", "Measure ID", "Compare to National", "Denominator", "Score", "Lower Estimate", "Higher Estimate"]]
#       6 medi_min = medicare[["County Name", "Measure Name", "Measure ID", "Score"]]
#       7 u_min = u_visits[["County Name", "Measure Name", "Measure ID", "Compared to National", "Denominator", "Score", "Lower Estimate", "Higher Estimate" ]]
#
# NameError: name 'readdmissions' is not defined
