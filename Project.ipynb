# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Narrowing down the data to state, KS and MO
df_readmission = pd.read_csv('Data/Readmissions and Deaths - VA_07_10_2018.csv')
df_ks_mo = df_readmission[(df_readmission['State']=='KS')|(df_readmission['State']=='MO')]
df_ks_mo.head()
# Out:
#     Provider_ID                     Hospital Name                 Address  \
# 252      17005F  COLMERY-O'NEIL VA MEDICAL CENTER  2200 SW GAGE BOULEVARD
# 253      17005F  COLMERY-O'NEIL VA MEDICAL CENTER  2200 SW GAGE BOULEVARD
# 254      17005F  COLMERY-O'NEIL VA MEDICAL CENTER  2200 SW GAGE BOULEVARD
# 255      17005F  COLMERY-O'NEIL VA MEDICAL CENTER  2200 SW GAGE BOULEVARD
# 256      17005F  COLMERY-O'NEIL VA MEDICAL CENTER  2200 SW GAGE BOULEVARD
#
#        City State  ZIP Code   County  \
# 252  TOPEKA    KS     66622  SHAWNEE
# 253  TOPEKA    KS     66622  SHAWNEE
# 254  TOPEKA    KS     66622  SHAWNEE
# 255  TOPEKA    KS     66622  SHAWNEE
# 256  TOPEKA    KS     66622  SHAWNEE
#
#                                           Measure Name    Measure ID  \
# 252  Acute Myocardial Infarction (AMI) 30-Day Morta...   MORT-30-AMI
# 253           Heart failure (HF) 30-Day Mortality Rate    MORT-30-HF
# 254               Pneumonia (PN) 30-Day Mortality Rate    MORT-30-PN
# ...
